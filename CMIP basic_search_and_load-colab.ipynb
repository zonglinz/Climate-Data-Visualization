# %% [markdown]
# # Google Cloud CMIP6 Public Data: Basic Python Example
#
# This notebooks shows how to query the catalog and load the data using python

# %%
! pip install --upgrade xarray zarr gcsfs cftime nc-time-axis
# Out:
# I0505 20:05:46.841136  518877 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# Requirement already satisfied: xarray in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (2026.4.0)
# Requirement already satisfied: zarr in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (3.2.1)
# Requirement already satisfied: gcsfs in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (2026.4.0)
# Requirement already satisfied: cftime in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (1.6.5)
# Requirement already satisfied: nc-time-axis in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.26 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from xarray) (2.1.1)
# Requirement already satisfied: packaging>=24.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: donfig>=0.8 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from zarr) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from zarr) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from zarr) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.13 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from zarr) (4.15.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (3.13.5)
# Requirement already satisfied: decorator>4.1.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (5.2.1)
# Requirement already satisfied: fsspec>=2026.4.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (2026.4.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (1.2.2)
# Requirement already satisfied: google-auth>=1.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (2.41.1)
# Requirement already satisfied: google-cloud-storage-control in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (1.11.0)
# Requirement already satisfied: google-cloud-storage>=3.9.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (3.10.1)
# Requirement already satisfied: requests in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from gcsfs) (2.32.3)
# Requirement already satisfied: matplotlib in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from nc-time-axis) (3.9.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->gcsfs) (1.23.0)
# Requirement already satisfied: pyyaml in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from donfig>=0.8->zarr) (6.0.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs) (4.9.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage>=3.9.0->gcsfs) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage>=3.9.0->gcsfs) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage>=3.9.0->gcsfs) (2.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from pandas>=2.2->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from pandas>=2.2->xarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from pandas>=2.2->xarray) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from requests->gcsfs) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from requests->gcsfs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from requests->gcsfs) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from requests->gcsfs) (2024.8.30)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage-control->gcsfs) (1.80.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage-control->gcsfs) (1.26.1)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage-control->gcsfs) (6.32.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-cloud-storage-control->gcsfs) (0.14.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from matplotlib->nc-time-axis) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from matplotlib->nc-time-axis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from matplotlib->nc-time-axis) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from matplotlib->nc-time-axis) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from matplotlib->nc-time-axis) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from matplotlib->nc-time-axis) (3.2.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=3.9.0->gcsfs) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-storage-control->gcsfs) (1.80.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.6.1)
# Requirement already satisfied: six>=1.5 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/generalclasher/miniforge3/envs/dsc80/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.3.1)

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import gcsfs

xr.set_options(display_style='html')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
plt.rcParams['figure.figsize'] = 12, 6

# %% [markdown]
# ## Browse Catalog
#
# The data catatalog is stored as a CSV file. Here we read it with Pandas.

# %%
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon          ps         gn
# 1     Amon        rsds         gn
# 2     Amon        rlus         gn
# 3     Amon        rlds         gn
# 4     Amon         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %% [markdown]
# The columns of the dataframe correspond to the CMI6 controlled vocabulary. A beginners' guide to these terms is available in [this document](https://docs.google.com/document/d/1yUx6jr9EdedCOLd--CPdTfGDwEwzPpCF6p1jRmqx-0Q).
#
# Here we filter the data to find monthly surface air temperature for historical experiments.

# %%
df_ta = df.query("activity_id=='CMIP' & table_id == 'Amon' & variable_id == 'tas' & experiment_id == 'historical'")
df_ta
# Out:
#        activity_id       institution_id      source_id experiment_id  \
# 973           CMIP            NOAA-GFDL      GFDL-ESM4    historical
# 1766          CMIP            NOAA-GFDL      GFDL-ESM4    historical
# 8074          CMIP            NOAA-GFDL       GFDL-CM4    historical
# 22185         CMIP                 IPSL   IPSL-CM6A-LR    historical
# 22298         CMIP                 IPSL   IPSL-CM6A-LR    historical
# ...            ...                  ...            ...           ...
# 522952        CMIP                  MRI     MRI-ESM2-0    historical
# 523274        CMIP                  MRI     MRI-ESM2-0    historical
# 523712        CMIP                 CMCC   CMCC-CM2-SR5    historical
# 523721        CMIP                 CMCC   CMCC-CM2-SR5    historical
# 523769        CMIP  EC-Earth-Consortium  EC-Earth3-Veg    historical
#
#        member_id table_id variable_id grid_label  \
# 973     r3i1p1f1     Amon         tas        gr1
# 1766    r2i1p1f1     Amon         tas        gr1
# 8074    r1i1p1f1     Amon         tas        gr1
# 22185   r8i1p1f1     Amon         tas         gr
# 22298   r2i1p1f1     Amon         tas         gr
# ...          ...      ...         ...        ...
# 522952  r7i1p1f1     Amon         tas         gn
# 523274  r6i1p1f1     Amon         tas         gn
# 523712  r3i1p2f1     Amon         tas         gn
# 523721  r2i1p2f1     Amon         tas         gn
# 523769  r1i1p1f1     Amon         tas         gr
#
#                                                    zstore  dcpp_init_year  \
# 973     gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 1766    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 8074    gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 22185   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 22298   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# ...                                                   ...             ...
# 522952  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 523274  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 523712  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
# 523721  gs://cmip6/CMIP6/CMIP/CMCC/CMCC-CM2-SR5/histor...             NaN
# 523769  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
#
#          version
# 973     20180701
# 1766    20180701
# 8074    20180701
# 22185   20180803
# 22298   20180803
# ...          ...
# 522952  20210813
# 523274  20210907
# 523712  20211108
# 523721  20211109
# 523769  20211207
#
# [635 rows x 11 columns]

# %% [markdown]
# Now we do further filtering to find just the models from NCAR.

# %%
df_ta_ncar = df_ta.query('institution_id == "NCAR"')
df_ta_ncar
# Out:
#        activity_id institution_id        source_id experiment_id  member_id  \
# 56049         CMIP           NCAR      CESM2-WACCM    historical   r2i1p1f1
# 56143         CMIP           NCAR      CESM2-WACCM    historical   r3i1p1f1
# 56326         CMIP           NCAR      CESM2-WACCM    historical   r1i1p1f1
# 59875         CMIP           NCAR            CESM2    historical   r1i1p1f1
# 61655         CMIP           NCAR            CESM2    historical   r4i1p1f1
# 61862         CMIP           NCAR            CESM2    historical   r5i1p1f1
# 62691         CMIP           NCAR            CESM2    historical   r2i1p1f1
# 63131         CMIP           NCAR            CESM2    historical   r3i1p1f1
# 63266         CMIP           NCAR            CESM2    historical   r6i1p1f1
# 64615         CMIP           NCAR            CESM2    historical   r8i1p1f1
# 64914         CMIP           NCAR            CESM2    historical   r7i1p1f1
# 64983         CMIP           NCAR            CESM2    historical   r9i1p1f1
# 66341         CMIP           NCAR            CESM2    historical  r10i1p1f1
# 200772        CMIP           NCAR            CESM2    historical  r11i1p1f1
# 385224        CMIP           NCAR        CESM2-FV2    historical   r1i1p1f1
# 386297        CMIP           NCAR  CESM2-WACCM-FV2    historical   r1i1p1f1
# 420771        CMIP           NCAR  CESM2-WACCM-FV2    historical   r3i1p1f1
# 421251        CMIP           NCAR  CESM2-WACCM-FV2    historical   r2i1p1f1
# 422013        CMIP           NCAR        CESM2-FV2    historical   r3i1p1f1
# 422459        CMIP           NCAR        CESM2-FV2    historical   r2i1p1f1
#
#        table_id variable_id grid_label  \
# 56049      Amon         tas         gn
# 56143      Amon         tas         gn
# 56326      Amon         tas         gn
# 59875      Amon         tas         gn
# 61655      Amon         tas         gn
# 61862      Amon         tas         gn
# 62691      Amon         tas         gn
# 63131      Amon         tas         gn
# 63266      Amon         tas         gn
# 64615      Amon         tas         gn
# 64914      Amon         tas         gn
# 64983      Amon         tas         gn
# 66341      Amon         tas         gn
# 200772     Amon         tas         gn
# 385224     Amon         tas         gn
# 386297     Amon         tas         gn
# 420771     Amon         tas         gn
# 421251     Amon         tas         gn
# 422013     Amon         tas         gn
# 422459     Amon         tas         gn
#
#                                                    zstore  dcpp_init_year  \
# 56049   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 56143   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 56326   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 59875   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 61655   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r4...             NaN
# 61862   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r5...             NaN
# 62691   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r2...             NaN
# 63131   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r3...             NaN
# 63266   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r6...             NaN
# 64615   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r8...             NaN
# 64914   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r7...             NaN
# 64983   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r9...             NaN
# 66341   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 200772  gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 385224  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 386297  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 420771  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 421251  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 422013  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 422459  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
#
#          version
# 56049   20190227
# 56143   20190227
# 56326   20190227
# 59875   20190308
# 61655   20190308
# 61862   20190308
# 62691   20190308
# 63131   20190308
# 63266   20190308
# 64615   20190311
# 64914   20190311
# 64983   20190311
# 66341   20190313
# 200772  20190514
# 385224  20191120
# 386297  20191120
# 420771  20200226
# 421251  20200226
# 422013  20200226
# 422459  20200226

# %% [markdown]
# ## Load Data
#
# Now we will load a single store using gcsfs, zarr, and xarray.

# %%
# this only needs to be created once
gcs = gcsfs.GCSFileSystem(token='anon')

# get the path to a specific zarr store (the first one from the dataframe above)
zstore = df_ta_ncar.loc[59875].zstore

# create a mutable-mapping-style interface to the store
mapper = gcs.get_mapper(zstore)

# open it using xarray and zarr
ds = xr.open_zarr(mapper, consolidated=True)
ds
# Out:
# I0505 19:45:15.596295  519502 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0505 19:45:15.608603  519522 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(88, generation: 1)
# <xarray.Dataset> Size: 438MB
# Dimensions:    (time: 1980, lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * time       (time) object 16kB 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#     lat_bnds   (lat, nbnd) float32 2kB ...
#     lon_bnds   (lon, nbnd) float32 2kB ...
#     time_bnds  (time, nbnd) object 32kB ...
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (time, lat, lon) float32 438MB ...
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   674885.0
#     branch_time_in_parent:  219000.0
#     case_id:                15
#     ...                     ...
#     table_id:               Amon
#     tracking_id:            hdl:21.14100/d9a7225a-49c3-4470-b7ab-a8180926f839
#     variable_id:            tas
#     variant_info:           CMIP6 20th century experiments (1850-2014) with C...
#     variant_label:          r1i1p1f1
#     status:                 2019-10-25;created;by nhn2@columbia.edu

# %% [markdown]
# Plot a map from a specific date.

# %%
ds.tas.sel(time='1950-01').squeeze().plot()

# %% [markdown]
# Create a timeseries of global-average surface air temperature. For this we need the area weighting factor for each gridpoint.

# %%
df_area = df.query("variable_id == 'areacella' & source_id == 'CESM2'")
ds_area = xr.open_zarr(gcs.get_mapper(df_area.zstore.values[0]), consolidated=True)
ds_area
# Out:
# <xarray.Dataset> Size: 229kB
# Dimensions:    (lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#     lat_bnds   (lat, nbnd) float32 2kB ...
#     lon_bnds   (lon, nbnd) float32 2kB ...
# Dimensions without coordinates: nbnd
# Data variables:
#     areacella  (lat, lon) float32 221kB ...
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          no parent
#     branch_time_in_child:   711385.0
#     branch_time_in_parent:  0.0
#     case_id:                38
#     ...                     ...
#     table_id:               fx
#     tracking_id:            hdl:21.14100/23fa9dc3-4f8f-4943-b99b-58eb804c06f0
#     variable_id:            areacella
#     variant_info:           f.e21.FHIST_BGC.f09_f09_mg17.CMIP6-AMIP.001
# \n
# \...
#     variant_label:          r1i1p1f1
#     status:                 2019-11-04;created;by nhn2@columbia.edu

# %%
total_area = ds_area.areacella.sum(dim=['lon', 'lat'])
ta_timeseries = (ds.tas * ds_area.areacella).sum(dim=['lon', 'lat']) / total_area
ta_timeseries
# Out:
# <xarray.DataArray (time: 1980)> Size: 8kB
# array([285.2367 , 285.49353, 286.10147, ..., 288.3483 , 287.31396,
#        286.56613], dtype=float32)
# Coordinates:
#   * time     (time) object 16kB 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes: (12/19)
#     cell_measures:  area: areacella
#     time:           time
#     type:           real
#     cell_methods:   area: sum
#     comment:        Cell areas for any grid used to report atmospheric variab...
#     description:    Cell areas for any grid used to report atmospheric variab...
#     ...             ...
#     standard_name:  cell_area
#     time_label:     None
#     time_title:     No temporal dimensions ... fixed field
#     title:          Grid-Cell Area for Atmospheric Grid Variables
#     units:          m2
#     variable_id:    areacella

# %% [markdown]
# By default the data are loaded lazily, as Dask arrays. Here we trigger computation explicitly.

# %%
ta_timeseries.load()
# Out:
# <xarray.DataArray (time: 1980)> Size: 8kB
# array([285.2367 , 285.49353, 286.10147, ..., 288.3483 , 287.31396,
#        286.56613], dtype=float32)
# Coordinates:
#   * time     (time) object 16kB 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes: (12/19)
#     cell_measures:  area: areacella
#     time:           time
#     type:           real
#     cell_methods:   area: sum
#     comment:        Cell areas for any grid used to report atmospheric variab...
#     description:    Cell areas for any grid used to report atmospheric variab...
#     ...             ...
#     standard_name:  cell_area
#     time_label:     None
#     time_title:     No temporal dimensions ... fixed field
#     title:          Grid-Cell Area for Atmospheric Grid Variables
#     units:          m2
#     variable_id:    areacella

# %%
ta_timeseries.plot(label='monthly')
ta_timeseries.rolling(time=12).mean().plot(label='12 month rolling mean')
plt.legend()
plt.title('Global Mean Surface Air Temperature')
# Out:
# Text(0.5, 1.0, 'Global Mean Surface Air Temperature')

# %% [markdown]
# Or, we can select e.g. San Diego

# %%
sd_time_series = ds.tas.sel(lon=360-117.1611, lat=32.7157, method='nearest')

# %%
sd_time_series.plot(label='monthly')
sd_time_series.rolling(time=12).mean().plot(label='12 month rolling mean')
plt.legend()
plt.title('San Diego Surface Air Temperature')
# Out:
# Text(0.5, 1.0, 'San Diego Surface Air Temperature')

# %%
(sd_time_series.rolling(time=12).mean()-sd_time_series.sel(time=slice("1850","1900")).mean()).plot(label='12 month rolling mean')
plt.axhline(0.)

# %%
# Warming by Latitude: 2000-2014 vs 1850-1900
# Shows polar amplification — why northern countries are redder on the world map
import plotly.graph_objects as go

# Zonal mean (average over longitude) — much smaller than full grid
tas_zonal = ds.tas.resample(time="YE").mean().mean(dim="lon").load()  # shape: (years, lat)
years = tas_zonal.time.dt.year.values
lats = ds.lat.values

# Baseline and recent zonal means
base_mask   = years <= 1900
recent_mask = (years >= 2000) & (years <= 2014)
anomaly = (tas_zonal.isel(time=recent_mask).mean("time") -
           tas_zonal.isel(time=base_mask).mean("time")).values  # Kelvin diff = Celsius diff

fig = go.Figure(go.Bar(
    x=lats,
    y=anomaly,
    marker=dict(
        color=anomaly,
        colorscale="YlOrRd",
        cmin=0, cmax=3,
        showscale=True,
        colorbar=dict(title="°C")
    )
))
fig.update_layout(
    title="Warming by Latitude: 2000–2014 vs 1850–1900 Baseline",
    xaxis_title="Latitude",
    yaxis_title="Temperature Anomaly (°C)",
    xaxis=dict(tickvals=list(range(-90, 91, 30))),
    template="plotly_dark",
    height=450
)
fig.show()
